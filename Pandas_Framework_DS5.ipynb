# %% [markdown]
# Pandas Framework Overview

# %%
G=7

# %%
a=6

# %%
a+G
# Out:
# 13

# %%
# !pwd
# Out:
# /content/drive/MyDrive/bc

# %%
ls
# Out:
# breast-cancer.csv  data.csv

# %%
cd drive
# Out:
# [Errno 2] No such file or directory: 'drive'
# /content/drive/MyDrive/bc

# %%
pwd
# Out:
# '/content/drive/MyDrive/bc'

# %%
ls
# Out:
# breast-cancer.csv  data.csv

# %%
cd MyDrive
# Out:
# [Errno 2] No such file or directory: 'MyDrive'
# /content/drive/MyDrive/bc

# %%
# !mkdir bc

# %%
cd bc
# Out:
# /content/drive/MyDrive/bc/bc

# %%
# !wget 'https://datahub.io/machine-learning/breast-cancer/r/breast-cancer.csv'
# Out:
# --2022-04-05 17:36:48--  https://datahub.io/machine-learning/breast-cancer/r/breast-cancer.csv
# Resolving datahub.io (datahub.io)... 104.21.40.221, 172.67.157.38, 2606:4700:3030::ac43:9d26, ...
# Connecting to datahub.io (datahub.io)|104.21.40.221|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://pkgstore.datahub.io/machine-learning/breast-cancer/breast-cancer_csv/data/cfade1d9730bf286d3a83abf7d48829d/breast-cancer_csv.csv [following]
# --2022-04-05 17:36:48--  https://pkgstore.datahub.io/machine-learning/breast-cancer/breast-cancer_csv/data/cfade1d9730bf286d3a83abf7d48829d/breast-cancer_csv.csv
# Resolving pkgstore.datahub.io (pkgstore.datahub.io)... 104.21.40.221, 172.67.157.38, 2606:4700:3033::6815:28dd, ...
# Connecting to pkgstore.datahub.io (pkgstore.datahub.io)|104.21.40.221|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19021 (19K) [text/csv]
# Saving to: ‘breast-cancer.csv’
#
# ...

# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('/content/drive/MyDrive/Stars.csv')
data
# Out:
#      Temperature              L          R    A_M  Color Spectral_Class  Type
# 0           3068       0.002400     0.1700  16.12    Red              M     0
# 1           3042       0.000500     0.1542  16.60    Red              M     0
# 2           2600       0.000300     0.1020  18.70    Red              M     0
# 3           2800       0.000200     0.1600  16.65    Red              M     0
# 4           1939       0.000138     0.1030  20.06    Red              M     0
# ..           ...            ...        ...    ...    ...            ...   ...
# 235        38940  374830.000000  1356.0000  -9.93   Blue              O     5
# 236        30839  834042.000000  1194.0000 -10.63   Blue              O     5
# 237         8829  537493.000000  1423.0000 -10.73  White              A     5
# 238         9235  404940.000000  1112.0000 -11.23  White              A     5
# 239        37882  294903.000000  1783.0000  -7.80   Blue              O     5
#
# [240 rows x 7 columns]

# %%
data1=pd.read_excel('/content/drive/MyDrive/electro2.xlsx')
data1
# Out:
#            E  5mv/s     10     30     50     60     70     80     90    100  \
# 0     0.0000 -0.083 -0.020 -0.060 -0.107 -0.134 -0.157 -0.165 -0.187 -0.190
# 1    10.0000 -0.058 -0.015 -0.043 -0.082 -0.103 -0.123 -0.130 -0.149 -0.155
# 2    20.0000 -0.045 -0.012 -0.037 -0.068 -0.085 -0.103 -0.110 -0.126 -0.132
# 3    30.0000 -0.037 -0.012 -0.033 -0.059 -0.074 -0.089 -0.095 -0.109 -0.116
# 4    40.0000 -0.033 -0.011 -0.028 -0.052 -0.065 -0.078 -0.084 -0.097 -0.103
# ..       ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 296  40.0000 -0.016 -0.029 -0.084 -0.190 -0.180 -0.217 -0.259 -0.330 -0.332
# 297  30.0000 -0.016 -0.028 -0.080 -0.180 -0.172 -0.207 -0.247 -0.320 -0.318
# 298  20.0000 -0.015 -0.028 -0.078 -0.170 -0.166 -0.199 -0.238 -0.310 -0.304
# 299  10.0000 -0.014 -0.027 -0.075 -0.160 -0.159 -0.193 -0.227 -0.290 -0.293
# 300   0.0011 -0.340 -0.015 -0.048 -0.140 -0.160 -0.155 -0.186 -0.220 -0.290
#
# ...

# %%
temp=data['Temperature'].values

# %%
i=['pouriya','mahdi','ali','sana']
optic=[10,20,18,17]
algebra=[20,20,9,16]
pe=[16,10,8,18]

# %%
s={'Optic':optic,'Algebra':algebra,'PE':pe}
df=pd.DataFrame(s,index=i,columns=['Optic','Algebra','PE'])
df
# Out:
#          Optic  Algebra  PE
# pouriya     10       20  16
# mahdi       20       20  10
# ali         18        9   8
# sana        17       16  18

# %%
s={'Optic':optic,'Algebra':algebra,'PE':pe}
df=pd.DataFrame(s,index=i,columns=s.keys())
df
# Out:
#          Optic  Algebra  PE
# pouriya     10       20  16
# mahdi       20       20  10
# ali         18        9   8
# sana        17       16  18

# %%
df.index
# Out:
# Index(['pouriya', 'mahdi', 'ali', 'sana'], dtype='object')

# %%
a=df.values
type(a)
# Out:
# numpy.ndarray

# %%
df.columns
# Out:
# Index(['Optic', 'Algebra', 'PE'], dtype='object')

# %%
df.loc['pouriya']['PE']
# Out:
# 16

# %%
df['math']=[18,10,12,16]

# %%
df
# Out:
#          Optic  Algebra  PE  math
# pouriya     10       20  16    18
# mahdi       20       20  10    10
# ali         18        9   8    12
# sana        17       16  18    16

# %%
df.loc[['pouriya','mahdi'],'Optic']=0.25

# %%
df
# Out:
#          Optic  Algebra  PE  math
# pouriya   0.25       20  16    18
# mahdi     0.25       20  10    10
# ali      18.00        9   8    12
# sana     17.00       16  18    16

# %%
pwd
# Out:
# '/content/drive/MyDrive/bc/bc'

# %%
df.to_csv('data.csv')
# !cp data.csv "/content/drive/MyDrive/bc"

# %%
data
# Out:
#      Temperature              L          R    A_M  Color Spectral_Class  Type
# 0           3068       0.002400     0.1700  16.12    Red              M     0
# 1           3042       0.000500     0.1542  16.60    Red              M     0
# 2           2600       0.000300     0.1020  18.70    Red              M     0
# 3           2800       0.000200     0.1600  16.65    Red              M     0
# 4           1939       0.000138     0.1030  20.06    Red              M     0
# ..           ...            ...        ...    ...    ...            ...   ...
# 235        38940  374830.000000  1356.0000  -9.93   Blue              O     5
# 236        30839  834042.000000  1194.0000 -10.63   Blue              O     5
# 237         8829  537493.000000  1423.0000 -10.73  White              A     5
# 238         9235  404940.000000  1112.0000 -11.23  White              A     5
# 239        37882  294903.000000  1783.0000  -7.80   Blue              O     5
#
# [240 rows x 7 columns]

# %%
c=data['Color'].values
q=np.unique(c)
q
# Out:
# array(['Blue', 'Blue White', 'Blue white', 'Blue-White', 'Blue-white',
#        'Orange', 'Orange-Red', 'Pale yellow orange', 'Red', 'White',
#        'White-Yellow', 'Whitish', 'Yellowish', 'Yellowish White', 'white',
#        'yellow-white', 'yellowish'], dtype=object)

# %%
data=data.replace({'Blue':0, 'Blue White':1, 'Blue white':1, 'Blue-White':1, 'Blue-white':1,
       'Orange':2, 'Orange-Red':3, 'Pale yellow orange':4, 'Red':5, 'White':6,
       'White-Yellow':7, 'Whitish':8, 'Yellowish':9, 'Yellowish White':10, 'white':6,
       'yellow-white':7, 'yellowish':9})

# %%
data
# Out:
#      Temperature              L          R    A_M  Color Spectral_Class  Type
# 0           3068       0.002400     0.1700  16.12      5              M     0
# 1           3042       0.000500     0.1542  16.60      5              M     0
# 2           2600       0.000300     0.1020  18.70      5              M     0
# 3           2800       0.000200     0.1600  16.65      5              M     0
# 4           1939       0.000138     0.1030  20.06      5              M     0
# ..           ...            ...        ...    ...    ...            ...   ...
# 235        38940  374830.000000  1356.0000  -9.93      0              O     5
# 236        30839  834042.000000  1194.0000 -10.63      0              O     5
# 237         8829  537493.000000  1423.0000 -10.73      6              A     5
# 238         9235  404940.000000  1112.0000 -11.23      6              A     5
# 239        37882  294903.000000  1783.0000  -7.80      0              O     5
#
# [240 rows x 7 columns]

# %%
sp=data['Spectral_Class'].values
q1=np.unique(sp)
q1
# Out:
# array(['A', 'B', 'F', 'G', 'K', 'M', 'O'], dtype=object)

# %%
data=data.replace({'A':0, 'B':1, 'F':2, 'G':3, 'K':4, 'M':5, 'O':6})

# %%
data
# Out:
#      Temperature              L          R    A_M  Color  Spectral_Class  Type
# 0           3068       0.002400     0.1700  16.12      5               5     0
# 1           3042       0.000500     0.1542  16.60      5               5     0
# 2           2600       0.000300     0.1020  18.70      5               5     0
# 3           2800       0.000200     0.1600  16.65      5               5     0
# 4           1939       0.000138     0.1030  20.06      5               5     0
# ..           ...            ...        ...    ...    ...             ...   ...
# 235        38940  374830.000000  1356.0000  -9.93      0               6     5
# 236        30839  834042.000000  1194.0000 -10.63      0               6     5
# 237         8829  537493.000000  1423.0000 -10.73      6               0     5
# 238         9235  404940.000000  1112.0000 -11.23      6               0     5
# 239        37882  294903.000000  1783.0000  -7.80      0               6     5
#
# [240 rows x 7 columns]

# %%
df
# Out:
#          Optic  Algebra  PE  math
# pouriya   0.25       20  16    18
# mahdi     0.25       20  10    10
# ali      18.00        9   8    12
# sana     17.00       16  18    16

# %%
df=df.drop('Optic',axis=1)

# %%
df
# Out:
#          Algebra  PE  math
# pouriya       20  16    18
# mahdi         20  10    10
# ali            9   8    12
# sana          16  18    16

# %%
df=df.drop('sana',axis=0)

# %%
df
# Out:
#          Algebra  PE  math
# pouriya       20  16    18
# mahdi         20  10    10
# ali            9   8    12

# %%
data
# Out:
#      Temperature              L          R    A_M  Color  Spectral_Class  Type
# 0           3068       0.002400     0.1700  16.12      5               5     0
# 1           3042       0.000500     0.1542  16.60      5               5     0
# 2           2600       0.000300     0.1020  18.70      5               5     0
# 3           2800       0.000200     0.1600  16.65      5               5     0
# 4           1939       0.000138     0.1030  20.06      5               5     0
# ..           ...            ...        ...    ...    ...             ...   ...
# 235        38940  374830.000000  1356.0000  -9.93      0               6     5
# 236        30839  834042.000000  1194.0000 -10.63      0               6     5
# 237         8829  537493.000000  1423.0000 -10.73      6               0     5
# 238         9235  404940.000000  1112.0000 -11.23      6               0     5
# 239        37882  294903.000000  1783.0000  -7.80      0               6     5
#
# [240 rows x 7 columns]

# %%
data.head()
# Out:
#    Temperature         L       R    A_M  Color  Spectral_Class  Type
# 0         3068  0.002400  0.1700  16.12      5               5     0
# 1         3042  0.000500  0.1542  16.60      5               5     0
# 2         2600  0.000300  0.1020  18.70      5               5     0
# 3         2800  0.000200  0.1600  16.65      5               5     0
# 4         1939  0.000138  0.1030  20.06      5               5     0

# %%
data.tail()
# Out:
#      Temperature         L       R    A_M  Color  Spectral_Class  Type
# 235        38940  374830.0  1356.0  -9.93      0               6     5
# 236        30839  834042.0  1194.0 -10.63      0               6     5
# 237         8829  537493.0  1423.0 -10.73      6               0     5
# 238         9235  404940.0  1112.0 -11.23      6               0     5
# 239        37882  294903.0  1783.0  -7.80      0               6     5

# %%
data.head(10)
# Out:
#    Temperature         L       R    A_M  Color  Spectral_Class  Type
# 0         3068  0.002400  0.1700  16.12      5               5     0
# 1         3042  0.000500  0.1542  16.60      5               5     0
# 2         2600  0.000300  0.1020  18.70      5               5     0
# 3         2800  0.000200  0.1600  16.65      5               5     0
# 4         1939  0.000138  0.1030  20.06      5               5     0
# 5         2840  0.000650  0.1100  16.98      5               5     0
# 6         2637  0.000730  0.1270  17.22      5               5     0
# 7         2600  0.000400  0.0960  17.40      5               5     0
# 8         2650  0.000690  0.1100  17.45      5               5     0
# 9         2700  0.000180  0.1300  16.05      5               5     0

# %%
data.sort_values(by='Temperature',ascending=False)
# Out:
#      Temperature              L         R    A_M  Color  Spectral_Class  Type
# 101        40000  813000.000000    14.000  -6.23      0               6     4
# 30         39000  204000.000000    10.600  -4.70      0               6     3
# 235        38940  374830.000000  1356.000  -9.93      0               6     5
# 231        38234  272830.000000  1356.000  -9.29      0               6     5
# 239        37882  294903.000000  1783.000  -7.80      0               6     5
# ..           ...            ...       ...    ...    ...             ...   ...
# 6           2637       0.000730     0.127  17.22      5               5     0
# 78          2621       0.000600     0.098  12.81      5               5     1
# 7           2600       0.000400     0.096  17.40      5               5     0
# 2           2600       0.000300     0.102  18.70      5               5     0
# 4           1939       0.000138     0.103  20.06      5               5     0
#
# [240 rows x 7 columns]

# %%
data.sort_index(axis=1,ascending=True)
# Out:
#        A_M  Color              L          R  Spectral_Class  Temperature  Type
# 0    16.12      5       0.002400     0.1700               5         3068     0
# 1    16.60      5       0.000500     0.1542               5         3042     0
# 2    18.70      5       0.000300     0.1020               5         2600     0
# 3    16.65      5       0.000200     0.1600               5         2800     0
# 4    20.06      5       0.000138     0.1030               5         1939     0
# ..     ...    ...            ...        ...             ...          ...   ...
# 235  -9.93      0  374830.000000  1356.0000               6        38940     5
# 236 -10.63      0  834042.000000  1194.0000               6        30839     5
# 237 -10.73      6  537493.000000  1423.0000               0         8829     5
# 238 -11.23      6  404940.000000  1112.0000               0         9235     5
# 239  -7.80      0  294903.000000  1783.0000               6        37882     5
#
# [240 rows x 7 columns]

# %%
data.corr()
# Out:
#                 Temperature         L         R       A_M     Color  \
# Temperature        1.000000  0.393404  0.064216 -0.420261 -0.724016
# L                  0.393404  1.000000  0.526516 -0.692619 -0.374375
# R                  0.064216  0.526516  1.000000 -0.608728 -0.012290
# A_M               -0.420261 -0.692619 -0.608728  1.000000  0.385944
# Color             -0.724016 -0.374375 -0.012290  0.385944  1.000000
# Spectral_Class    -0.207852  0.275280  0.097124 -0.085840  0.126857
# Type               0.411129  0.676845  0.660975 -0.955276 -0.356213
#
#                 Spectral_Class      Type
# Temperature          -0.207852  0.411129
# L                     0.275280  0.676845
# R                     0.097124  0.660975
# A_M                  -0.085840 -0.955276
# Color                 0.126857 -0.356213
# Spectral_Class        1.000000 -0.049131
# Type                 -0.049131  1.000000

# %%
data.cov()
# Out:
#                  Temperature             L             R           A_M  \
# Temperature     9.124882e+07  6.742997e+08  3.172328e+05 -4.228285e+04
# L               6.742997e+08  3.219593e+10  4.885772e+07 -1.308962e+06
# R               3.172328e+05  4.885772e+07  2.674501e+05 -3.315712e+03
# A_M            -4.228285e+04 -1.308962e+06 -3.315712e+03  1.109338e+02
# Color          -1.803796e+04 -1.751995e+05 -1.657693e+01  1.060186e+01
# Spectral_Class -4.149695e+03  1.032339e+05  1.049769e+02 -1.889590e+00
# Type            6.721119e+03  2.078451e+05  5.850011e+02 -1.721911e+01
#
#                         Color  Spectral_Class           Type
# Temperature     -18037.961088    -4149.695293    6721.119247
# L              -175199.507770   103233.945911  207845.082775
# R                  -16.576931      104.976862     585.001051
# A_M                 10.601858       -1.889590     -17.219111
# Color                6.802232        0.691492      -1.589958
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Temperature     240 non-null    int64
#  1   L               240 non-null    float64
#  2   R               240 non-null    float64
#  3   A_M             240 non-null    float64
#  4   Color           240 non-null    int64
#  5   Spectral_Class  240 non-null    int64
#  6   Type            240 non-null    int64
# dtypes: float64(3), int64(4)
# memory usage: 13.2 KB

# %%
data.describe()
# Out:
#         Temperature              L            R         A_M       Color  \
# count    240.000000     240.000000   240.000000  240.000000  240.000000
# mean   10497.462500  107188.361635   237.157781    4.382396    3.366667
# std     9552.425037  179432.244940   517.155763   10.532512    2.608109
# min     1939.000000       0.000080     0.008400  -11.920000    0.000000
# 25%     3344.250000       0.000865     0.102750   -6.232500    1.000000
# 50%     5776.000000       0.070500     0.762500    8.313000    5.000000
# 75%    15055.500000  198050.000000    42.750000   13.697500    5.000000
# max    40000.000000  849420.000000  1948.500000   20.060000   10.000000
#
#        Spectral_Class        Type
# count      240.000000  240.000000
# mean         3.758333    2.500000
# std          2.090007    1.711394
# min          0.000000    0.000000
# 25%          1.000000    1.000000
# 50%          5.000000    2.500000
# 75%          5.000000    4.000000
# max          6.000000    5.000000

# %%
corr=data.corr()

# %%
import seaborn as sns
h=sns.heatmap(corr,vmin=-1,vmax=1,annot=True)
